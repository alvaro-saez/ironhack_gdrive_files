# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import numpy as np
import pandas as pd
import re

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database
pokemon = pd.read_csv("../Pokemon.csv", sep=",", index_col=False)
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here
type1 = pokemon["Type 1"]
type1_distinct = type1.unique()
type1_distinct
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
type2 = pokemon["Type 2"]
type2_distinct = type2.unique()
type2_distinct
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
type_1_2_full = pokemon[["Type 1","Type 2"]]
type_1_2_full
# Out:
#       Type 1  Type 2
# 0      Grass  Poison
# 1      Grass  Poison
# 2      Grass  Poison
# 3      Grass  Poison
# 4       Fire     NaN
# ..       ...     ...
# 795     Rock   Fairy
# 796     Rock   Fairy
# 797  Psychic   Ghost
# 798  Psychic    Dark
# 799     Fire   Water
#
# [800 rows x 2 columns]

# %%
type_1_2_full_array = np.array(type1,type2).reshape(2,400)
type_1_2_full_array
# Out:
# array([['Grass', 'Grass', 'Grass', 'Grass', 'Fire', 'Fire', 'Fire',
#         'Fire', 'Fire', 'Water', 'Water', 'Water', 'Water', 'Bug', 'Bug',
#         'Bug', 'Bug', 'Bug', 'Bug', 'Bug', 'Normal', 'Normal', 'Normal',
#         'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Poison',
#         'Poison', 'Electric', 'Electric', 'Ground', 'Ground', 'Poison',
#         'Poison', 'Poison', 'Poison', 'Poison', 'Poison', 'Fairy',
#         'Fairy', 'Fire', 'Fire', 'Normal', 'Normal', 'Poison', 'Poison',
#         'Grass', 'Grass', 'Grass', 'Bug', 'Bug', 'Bug', 'Bug', 'Ground',
#         'Ground', 'Normal', 'Normal', 'Water', 'Water', 'Fighting',
#         'Fighting', 'Fire', 'Fire', 'Water', 'Water', 'Water', 'Psychic',
#         'Psychic', 'Psychic', 'Psychic', 'Fighting', 'Fighting',
#         'Fighting', 'Grass', 'Grass', 'Grass', 'Water', 'Water', 'Rock',
#         'Rock', 'Rock', 'Fire', 'Fire', 'Water', 'Water', 'Water',
# ...

# %%
type_1_2_distinct_array = np.unique(type_1_2_full_array)
type_1_2_distinct_array
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# way 1
pokemon_name = pokemon["Name"].str.replace(".*Mega","Mega",regex=True)
pokemon["Name"] = pokemon_name

# test transformed data
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# ...

# %%
#way 2
def clean_name(x):
    return re.sub(".*Mega","Mega",x)

pokemon["Name"] = pokemon["Name"].apply(clean_name)

# test transformed data
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# ...

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here
pokemon["A/D Ratio"] = pokemon["Attack"]/pokemon["Defense"]
pokemon
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 2      3             Venusaur    Grass  Poison    525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4           Charmander     Fire     NaN    309  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy    600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# ...

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here
pokemon["A/D Ratio"].max()
# Out:
# 9.0

# %%
pokemon.sort_values(["A/D Ratio"],ascending=False)
# Out:
#        #                Name   Type 1   Type 2  Total   HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic      NaN    600   50     180       20
# 347  318            Carvanha    Water     Dark    305   45      90       20
# 19    15       Mega Beedrill      Bug   Poison    495   65     150       40
# 453  408            Cranidos     Rock      NaN    350   67     125       40
# 348  319            Sharpedo    Water     Dark    460   70     120       40
# ..   ...                 ...      ...      ...    ...  ...     ...      ...
# 616  555  DarmanitanZen Mode     Fire  Psychic    540  105      30      105
# 103   95                Onix     Rock   Ground    385   35      45      160
# 484  436             Bronzor    Steel  Psychic    300   57      24       86
# 139  129            Magikarp    Water      NaN    200   20      10       55
# 230  213             Shuckle      Bug     Rock    505   20      10      230
#
# ...

# %%
pokemon_highest_adratio_raw = pokemon[pokemon["A/D Ratio"].isin([9.0])]
pokemon_highest_adratio_raw
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True        9.0

# %%
pokemon_highest_adratio_name = pokemon_highest_adratio_raw.iloc[0,1]
pokemon_highest_adratio_name
# Out:
# 'DeoxysAttack Forme'

# %%
#method 2
pokemon_highest_adratio_raw2 = pokemon.loc[(pokemon["A/D Ratio"]==9.0)]
pokemon_highest_adratio_raw2
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True        9.0

# %%
pokemon_highest_adratio_name2 = pokemon.iloc[429,1]
pokemon_highest_adratio_name2
# Out:
# 'DeoxysAttack Forme'

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here
pokemon["A/D Ratio"].min()
# Out:
# 0.043478260869565216

# %%
pokemon_lowest_adratio_raw = pokemon[pokemon["A/D Ratio"].isin([0.043478260869565216])]
pokemon_lowest_adratio_raw
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary  A/D Ratio
# 230      5           2      False   0.043478

# %%
pokemon_lowest_adratio_name = pokemon_lowest_adratio_raw.iloc[0,1]
pokemon_lowest_adratio_name
# Out:
# 'Shuckle'

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# your code here
def combo_type(arg1,arg2):
    if arg1!="null" and arg2!="null":
        return f"{arg1}-{arg2}"
    elif arg1!="null" and arg2=="null":
        return f"{arg1}"

# %%
pokemon["Type 2"] = pokemon["Type 2"].fillna("null")
pokemon["Type 2"]
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4        null
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
pokemon["Combo Type"] = pokemon.apply(lambda x: combo_type(x["Type 1"],x["Type 2"]), axis=1)
pokemon
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 2      3             Venusaur    Grass  Poison    525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4           Charmander     Fire    null    309  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy    600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here
pokemon_sorted = pokemon.sort_values(["A/D Ratio"],ascending=False).reset_index(drop=True) 
pokemon_sorted
# Out:
#        #                Name   Type 1   Type 2  Total   HP  Attack  Defense  \
# 0    386  DeoxysAttack Forme  Psychic     null    600   50     180       20
# 1    318            Carvanha    Water     Dark    305   45      90       20
# 2     15       Mega Beedrill      Bug   Poison    495   65     150       40
# 3    408            Cranidos     Rock     null    350   67     125       40
# 4    319            Sharpedo    Water     Dark    460   70     120       40
# ..   ...                 ...      ...      ...    ...  ...     ...      ...
# 795  555  DarmanitanZen Mode     Fire  Psychic    540  105      30      105
# 796   95                Onix     Rock   Ground    385   35      45      160
# 797  436             Bronzor    Steel  Psychic    300   57      24       86
# 798  129            Magikarp    Water     null    200   20      10       55
# 799  213             Shuckle      Bug     Rock    505   20      10      230
#
# ...

# %%
pokemon_top5_adratio = pokemon_sorted.iloc[[0,1,2,3,4],[1]]
pokemon_top5_adratio
# Out:
#                  Name
# 0  DeoxysAttack Forme
# 1            Carvanha
# 2       Mega Beedrill
# 3            Cranidos
# 4            Sharpedo

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
pokemon_top5_full = pokemon_sorted.loc[[0,1,2,3,4],["Name","Combo Type","A/D Ratio"]]
pokemon_top5_full
# Out:
#                  Name  Combo Type  A/D Ratio
# 0  DeoxysAttack Forme     Psychic      9.000
# 1            Carvanha  Water-Dark      4.500
# 2       Mega Beedrill  Bug-Poison      3.750
# 3            Cranidos        Rock      3.125
# 4            Sharpedo  Water-Dark      3.000

# %%
pokemon_top5_full_list=np.array(pokemon_top5_full).tolist()
pokemon_top5_full_list
# Out:
# [['DeoxysAttack Forme', 'Psychic', 9.0],
#  ['Carvanha', 'Water-Dark', 4.5],
#  ['Mega Beedrill', 'Bug-Poison', 3.75],
#  ['Cranidos', 'Rock', 3.125],
#  ['Sharpedo', 'Water-Dark', 3.0]]

# %%
#method 2 merge
pokemon_top5_ct = pokemon_sorted.loc[[0,1,2,3,4],["Name","Combo Type"]]
pokemon_top5_ct
# Out:
#                  Name  Combo Type
# 0  DeoxysAttack Forme     Psychic
# 1            Carvanha  Water-Dark
# 2       Mega Beedrill  Bug-Poison
# 3            Cranidos        Rock
# 4            Sharpedo  Water-Dark

# %%
pokemon_top5_rt = pokemon_sorted.loc[[0,1,2,3,4],["Name","A/D Ratio"]]
pokemon_top5_rt
# Out:
#                  Name  A/D Ratio
# 0  DeoxysAttack Forme      9.000
# 1            Carvanha      4.500
# 2       Mega Beedrill      3.750
# 3            Cranidos      3.125
# 4            Sharpedo      3.000

# %%
pokemon_top5_full2 = pd.merge(pokemon_top5_ct,pokemon_top5_rt)
pokemon_top5_full2
# Out:
#                  Name  Combo Type  A/D Ratio
# 0  DeoxysAttack Forme     Psychic      9.000
# 1            Carvanha  Water-Dark      4.500
# 2       Mega Beedrill  Bug-Poison      3.750
# 3            Cranidos        Rock      3.125
# 4            Sharpedo  Water-Dark      3.000

# %%
pokemon_top5_full_list2=np.array(pokemon_top5_full2).tolist()
pokemon_top5_full_list2
# Out:
# [['DeoxysAttack Forme', 'Psychic', 9.0],
#  ['Carvanha', 'Water-Dark', 4.5],
#  ['Mega Beedrill', 'Bug-Poison', 3.75],
#  ['Cranidos', 'Rock', 3.125],
#  ['Sharpedo', 'Water-Dark', 3.0]]

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
pokemon_sorted_top5_full_df = pokemon_sorted.loc[[0,1,2,3,4]]
pokemon_sorted_top5_full_df
# Out:
#      #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  386  DeoxysAttack Forme  Psychic    null    600  50     180       20
# 1  318            Carvanha    Water    Dark    305  45      90       20
# 2   15       Mega Beedrill      Bug  Poison    495  65     150       40
# 3  408            Cranidos     Rock    null    350  67     125       40
# 4  319            Sharpedo    Water    Dark    460  70     120       40
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 0      180       20    150           3       True      9.000     Psychic
# 1       65       20     65           3      False      4.500  Water-Dark
# 2       15       80    145           1      False      3.750  Bug-Poison
# 3       30       30     58           4      False      3.125        Rock
# 4       95       40     95           3      False      3.000  Water-Dark

# %%
pokemon_statistics_top5 = pokemon_sorted_top5_full_df._get_numeric_data()
pokemon_statistics_top5.index = pokemon_sorted_top5_full_df["Combo Type"]
pokemon_statistics_top5
# Out:
#               #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Combo Type
# Psychic     386    600  50     180       20      180       20    150
# Water-Dark  318    305  45      90       20       65       20     65
# Bug-Poison   15    495  65     150       40       15       80    145
# Rock        408    350  67     125       40       30       30     58
# Water-Dark  319    460  70     120       40       95       40     95
#
#             Generation  Legendary  A/D Ratio
# Combo Type
# Psychic              3       True      9.000
# Water-Dark           3      False      4.500
# Bug-Poison           1      False      3.750
# Rock                 4      False      3.125
# Water-Dark           3      False      3.000

# %%
pokemon_ct_top5_list = pokemon_sorted_top5_full_df["Combo Type"]
pokemon_ct_top5_list
# Out:
# 0       Psychic
# 1    Water-Dark
# 2    Bug-Poison
# 3          Rock
# 4    Water-Dark
# Name: Combo Type, dtype: object

# %%
pokemon_statistics = pokemon._get_numeric_data()
pokemon_statistics.index = pokemon["Combo Type"]
pokemon_statistics
# Out:
#                  #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Combo Type
# Grass-Poison     1    318  45      49       49       65       65     45
# Grass-Poison     2    405  60      62       63       80       80     60
# Grass-Poison     3    525  80      82       83      100      100     80
# Grass-Poison     3    625  80     100      123      122      120     80
# Fire             4    309  39      52       43       60       50     65
# ...            ...    ...  ..     ...      ...      ...      ...    ...
# Rock-Fairy     719    600  50     100      150      100      150     50
# Rock-Fairy     719    700  50     160      110      160      110    110
# Psychic-Ghost  720    600  80     110       60      150      130     70
# Psychic-Dark   720    680  80     160       60      170      130     80
# Fire-Water     721    600  80     110      120      130       90     70
#
#                Generation  Legendary  A/D Ratio
# Combo Type
# ...

# %%
pokemon_statistics_full_top5 = pokemon_statistics[pokemon_statistics.index.isin(pokemon_ct_top5_list)]
pokemon_statistics_full_top5
# Out:
#               #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Combo Type
# Bug-Poison   13    195  40      35       30       20       20     50
# Bug-Poison   14    205  45      25       50       25       25     35
# Bug-Poison   15    395  65      90       40       45       80     75
# Bug-Poison   15    495  65     150       40       15       80    145
# Bug-Poison   48    305  60      55       50       40       55     45
# ...         ...    ...  ..     ...      ...      ...      ...    ...
# Psychic     606    485  75      75       75      125       95     40
# Water-Dark  658    530  72      95       67      103       71    122
# Psychic     677    355  62      48       54       63       60     68
# Psychic     678    466  74      48       76       83       81    104
# Psychic     678    466  74      48       76       83       81    104
#
#             Generation  Legendary  A/D Ratio
# Combo Type
# Bug-Poison           1      False   1.166667
# ...

# %%
pokemon_statistics_full_bug_poison = pokemon_statistics_full_top5.loc["Bug-Poison",:]
pokemon_bug_poison_mean = pokemon_statistics_full_bug_poison.mean()
pokemon_bug_poison_mean_df = pd.DataFrame(pokemon_bug_poison_mean).transpose()
pokemon_bug_poison_mean_df.index=["Bug-Poison"]

pokemon_statistics_full_water_dark = pokemon_statistics_full_top5.loc["Water-Dark",:]
pokemon_water_dark_mean = pokemon_statistics_full_water_dark.mean()
pokemon_water_dark_mean_df = pd.DataFrame(pokemon_water_dark_mean).transpose()
pokemon_water_dark_mean_df.index=["Water-Dark"]

pokemon_statistics_full_psychic = pokemon_statistics_full_top5.loc["Psychic",:]
pokemon_psychic_mean = pokemon_statistics_full_psychic.mean()
pokemon_psychic_mean_df = pd.DataFrame(pokemon_psychic_mean).transpose()
pokemon_psychic_mean_df.index=["Psychic"]

pokemon_statistics_full_rock = pokemon_statistics_full_top5.loc["Rock",:]
pokemon_rock_mean = pokemon_statistics_full_rock.mean()
pokemon_rock_mean_df = pd.DataFrame(pokemon_rock_mean).transpose()
pokemon_rock_mean_df.index=["Rock"]

pokemon_bug_poison_mean_df
# Out:
#                      #       Total     HP     Attack    Defense  Sp. Atk  \
# Bug-Poison  199.166667  347.916667  53.75  68.333333  58.083333     42.5
#
#               Sp. Def      Speed  Generation  Legendary  A/D Ratio
# Bug-Poison  59.333333  65.916667    2.333333        0.0   1.315989

# %%
pokemon_final_mean_df = pokemon_bug_poison_mean_df
pokemon_final_mean_df = pokemon_final_mean_df.append(pokemon_water_dark_mean_df).append(pokemon_psychic_mean_df).append(pokemon_rock_mean_df)
pokemon_final_mean_df
# Out:
#                      #       Total         HP      Attack     Defense  \
# Bug-Poison  199.166667  347.916667  53.750000   68.333333   58.083333
# Water-Dark  347.666667  493.833333  69.166667  120.000000   65.166667
# Psychic     381.973684  464.552632  72.552632   64.947368   67.236842
# Rock        410.111111  409.444444  67.111111  103.333333  107.222222
#
#               Sp. Atk    Sp. Def      Speed  Generation  Legendary  A/D Ratio
# Bug-Poison  42.500000  59.333333  65.916667    2.333333   0.000000   1.315989
# Water-Dark  88.833333  63.500000  87.166667    3.166667   0.000000   2.291949
# Psychic     98.552632  82.394737  78.868421    3.342105   0.236842   1.164196
# Rock        40.555556  58.333333  32.888889    3.888889   0.111111   1.260091

# %% [markdown]
# #### ANOTHER METHOD WITH GROUPBY

# %%
pokemon
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 2      3             Venusaur    Grass  Poison    525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4           Charmander     Fire    null    309  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy    600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#we want to make the df only with the combo types of the top 5 pokemon with the higest rate:
#firstly, we create the list of their combo type
pokemon_ct_top5_list_unique = pokemon_ct_top5_list.unique().tolist()
pokemon_ct_top5_list_unique
# Out:
# ['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock']

# %%
#secondly, we make this df
pokemon_df_top5_combotype_ratio = pokemon[pokemon["Combo Type"].isin(pokemon_ct_top5_list_unique)]
pokemon_df_top5_combotype_ratio
# Out:
#        #            Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 16    13          Weedle      Bug  Poison    195  40      35       30
# 17    14          Kakuna      Bug  Poison    205  45      25       50
# 18    15        Beedrill      Bug  Poison    395  65      90       40
# 19    15   Mega Beedrill      Bug  Poison    495  65     150       40
# 53    48         Venonat      Bug  Poison    305  60      55       50
# ..   ...             ...      ...     ...    ...  ..     ...      ...
# 667  606        Beheeyem  Psychic    null    485  75      75       75
# 726  658        Greninja    Water    Dark    530  72      95       67
# 745  677          Espurr  Psychic    null    355  62      48       54
# 746  678    MeowsticMale  Psychic    null    466  74      48       76
# 747  678  MeowsticFemale  Psychic    null    466  74      48       76
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# ...

# %%
pokemon_df_top5_groupby = pokemon_df_top5_combotype_ratio.groupby(["Combo Type"])
pokemon_df_top5_groupby

# %%
pokemon_df_top5_mean = pokemon_df_top5_groupby.mean().sort_values(by='A/D Ratio', ascending=False)
pokemon_df_top5_mean
# Out:
#                      #       Total         HP      Attack     Defense  \
# Combo Type
# Water-Dark  347.666667  493.833333  69.166667  120.000000   65.166667
# Bug-Poison  199.166667  347.916667  53.750000   68.333333   58.083333
# Rock        410.111111  409.444444  67.111111  103.333333  107.222222
# Psychic     381.973684  464.552632  72.552632   64.947368   67.236842
#
#               Sp. Atk    Sp. Def      Speed  Generation  Legendary  A/D Ratio
# Combo Type
# Water-Dark  88.833333  63.500000  87.166667    3.166667   0.000000   2.291949
# Bug-Poison  42.500000  59.333333  65.916667    2.333333   0.000000   1.315989
# Rock        40.555556  58.333333  32.888889    3.888889   0.111111   1.260091
# Psychic     98.552632  82.394737  78.868421    3.342105   0.236842   1.164196
